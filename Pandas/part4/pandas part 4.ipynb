# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop("PassengerId",axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
d={"kay1":[3,4,5,6,7],
   "key2":[5,6,7,7,5],
   'key3':[4,5,6,7,8]

}

# %%
pd.DataFrame(d)
# Out:
#    kay1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     7     7
# 4     7     5     8

# %%
# pd.read_xls('taxonomy.csv.xls')

# %%
df1=pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2=pd.read_csv('taxonomy.csv')

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df.fillna("sudh",inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3      male  35.0      0      0            373450   8.0500  sudh        S
# 4      male  sudh      0      0            330877   8.4583  sudh        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000  sudh        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female  sudh      1      2        W./C. 6607  23.4500  sudh        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500  sudh        Q
#
# [890 rows x 11 columns]

# %%
g=df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_2681/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass  SibSp  Parch        Fare
# Survived
# 0           1390    304    181  12142.7199
# 1            666    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_2681/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass     SibSp     Parch       Fare
# Survived
# 0         2.531876  0.553734  0.329690  22.117887
# 1         1.953079  0.472141  0.466276  48.381611

# %%
g1=df.groupby('Pclass')

# %%
g1

# %%
g1.mean()
# Out:
# /tmp/ipykernel_2681/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived     SibSp     Parch       Fare
# Pclass
# 1       0.627907  0.413953  0.358140  84.299128
# 2       0.472826  0.402174  0.380435  20.662183
# 3       0.242363  0.615071  0.393075  13.675550

# %%
g1.sum()
# Out:
# /tmp/ipykernel_2681/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived  SibSp  Parch        Fare
# Pclass
# 1            135     89     77  18124.3125
# 2             87     74     70   3801.8417
# 3            119    302    193   6714.6951

# %%
g1.max()['Fare']
# Out:
# /tmp/ipykernel_2681/730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max()
# Out:
# /tmp/ipykernel_2681/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  Survived   Sex  SibSp  Parch      Ticket  \
# Pclass
# 1          Young, Miss. Marie Grice         1  male      3      4   WE/P 5735
# 2         del Carlo, Mr. Sebastiano         1  male      3      3   W/C 14208
# 3       van Melkebeke, Mr. Philemon         1  male      8      6  W./C. 6609
#
#             Fare Cabin Embarked
# Pclass
# 1       512.3292  sudh     sudh
# 2        73.5000  sudh        S
# 3        69.5500  sudh        S

# %%
g1.max().T
# Out:
# /tmp/ipykernel_2681/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
# Cabin                         sudh                       sudh
# Embarked                      sudh                          S
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# Sex                              male
# SibSp                               8
# Parch                               6
# Ticket                     W./C. 6609
# Fare                            69.55
# Cabin                            sudh
# Embarked                            S

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_2681/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
# Cabin                         sudh                       sudh
# Embarked                      sudh                          S
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# Sex                              male
# SibSp                               8
# Parch                               6
# Ticket                     W./C. 6609
# Fare                            69.55
# Cabin                            sudh
# Embarked                            S

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3      male  35.0      0      0            373450   8.0500  sudh        S
# 4      male  sudh      0      0            330877   8.4583  sudh        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000  sudh        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female  sudh      1      2        W./C. 6607  23.4500  sudh        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500  sudh        Q
#
# [890 rows x 11 columns]

# %%
df5=df[['Name','Survived','Pclass']][0:5]

# %%
df6=df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7=pd.concat([df5,df6],axis=1)

# %%
df7.fillna("sudh")
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                               sudh     sudh   sudh
# 6                                               sudh     sudh   sudh
# 7                                               sudh     sudh   sudh
# 8                                               sudh     sudh   sudh
# 9                                               sudh     sudh   sudh
#
#                                                 Name Survived Pclass
# 0                                               sudh     sudh   sudh
# 1                                               sudh     sudh   sudh
# 2                                               sudh     sudh   sudh
# 3                                               sudh     sudh   sudh
# 4                                               sudh     sudh   sudh
# 5                            McCarthy, Mr. Timothy J      0.0    1.0
# 6                     Palsson, Master. Gosta Leonard      0.0    3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0    3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)      1.0    2.0
# 9                    Sandstrom, Miss. Marguerite Rut      1.0    3.0

# %%
data1=pd.DataFrame({'kay1':[1,2,3,4,5],
                    'key2':[4,5,6,7,8],
                    'key3':[8,9,0,6,87]
                   })

# %%
data2=pd.DataFrame({'kay1':[1,2,3,42,54],
                    'key4':[4,3,6,7,8],
                    'key5':[8,9,0,6,87]
                   })

# %%
data1
# Out:
#    kay1  key2  key3
# 0     1     4     8
# 1     2     5     9
# 2     3     6     0
# 3     4     7     6
# 4     5     8    87

# %%
data2
# Out:
#    kay1  key4  key5
# 0     1     4     8
# 1     2     3     9
# 2     3     6     0
# 3    42     7     6
# 4    54     8    87

# %%
pd.merge(data1,data2)
# Out:
#    kay1  key2  key3  key4  key5
# 0     1     4     8     4     8
# 1     2     5     9     3     9
# 2     3     6     0     6     0

# %%
pd.merge(data1,data2,how='left')
# Out:
#    kay1  key2  key3  key4  key5
# 0     1     4     8   4.0   8.0
# 1     2     5     9   3.0   9.0
# 2     3     6     0   6.0   0.0
# 3     4     7     6   NaN   NaN
# 4     5     8    87   NaN   NaN

# %%
pd.merge(data1,data2,how='right')
# Out:
#    kay1  key2  key3  key4  key5
# 0     1   4.0   8.0     4     8
# 1     2   5.0   9.0     3     9
# 2     3   6.0   0.0     6     0
# 3    42   NaN   NaN     7     6
# 4    54   NaN   NaN     8    87

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    kay1  key2  key3  key4  key5
# 0     1   4.0   8.0   4.0   8.0
# 1     2   5.0   9.0   3.0   9.0
# 2     3   6.0   0.0   6.0   0.0
# 3     4   7.0   6.0   NaN   NaN
# 4     5   8.0  87.0   NaN   NaN
# 5    42   NaN   NaN   7.0   6.0
# 6    54   NaN   NaN   8.0  87.0

# %%
pd.merge(data1,data2,how='outer',on='key2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pd.merge(data1,data2,how='outer',on='key2')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'key2'

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     kay1_x  key2  key3  kay1_y  key4  key5
# 0        1     4     8       1     4     8
# 1        1     4     8       2     3     9
# 2        1     4     8       3     6     0
# 3        1     4     8      42     7     6
# 4        1     4     8      54     8    87
# 5        2     5     9       1     4     8
# 6        2     5     9       2     3     9
# 7        2     5     9       3     6     0
# 8        2     5     9      42     7     6
# 9        2     5     9      54     8    87
# 10       3     6     0       1     4     8
# 11       3     6     0       2     3     9
# 12       3     6     0       3     6     0
# 13       3     6     0      42     7     6
# 14       3     6     0      54     8    87
# 15       4     7     6       1     4     8
# 16       4     7     6       2     3     9
# 17       4     7     6       3     6     0
# 18       4     7     6      42     7     6
# 19       4     7     6      54     8    87
# 20       5     8    87       1     4     8
# 21       5     8    87       2     3     9
# 22       5     8    87       3     6     0
# 23       5     8    87      42     7     6
# 24       5     8    87      54     8    87

# %%
data1=pd.DataFrame({'kay1':[1,2,3,4,5],
                    'key2':[4,5,6,7,8],
                    'key3':[8,9,0,6,87]},
                    index=['a','b','c','d','e']
                   )

# %%
data2=pd.DataFrame({'kay11':[1,2,3,42,54],
                    'key4':[4,3,6,7,8],
                    'key5':[8,9,0,6,87]},
                   index=['a','b','h','i','j']
                   )

# %%
data1
# Out:
#    kay1  key2  key3
# a     1     4     8
# b     2     5     9
# c     3     6     0
# d     4     7     6
# e     5     8    87

# %%
data2
# Out:
#    kay11  key4  key5
# a      1     4     8
# b      2     3     9
# h      3     6     0
# i     42     7     6
# j     54     8    87

# %%
data1.join(data2)
# Out:
#    kay1  key2  key3  kay11  key4  key5
# a     1     4     8    1.0   4.0   8.0
# b     2     5     9    2.0   3.0   9.0
# c     3     6     0    NaN   NaN   NaN
# d     4     7     6    NaN   NaN   NaN
# e     5     8    87    NaN   NaN   NaN

# %%
data1.join(data2, how='right')
# Out:
#    kay1  key2  key3  kay11  key4  key5
# a   1.0   4.0   8.0      1     4     8
# b   2.0   5.0   9.0      2     3     9
# h   NaN   NaN   NaN      3     6     0
# i   NaN   NaN   NaN     42     7     6
# j   NaN   NaN   NaN     54     8    87

# %%
data1.join(data2, how='inner')
# Out:
#    kay1  key2  key3  kay11  key4  key5
# a     1     4     8      1     4     8
# b     2     5     9      2     3     9

# %%
data1.join(data2, how='outer')
# Out:
#    kay1  key2  key3  kay11  key4  key5
# a   1.0   4.0   8.0    1.0   4.0   8.0
# b   2.0   5.0   9.0    2.0   3.0   9.0
# c   3.0   6.0   0.0    NaN   NaN   NaN
# d   4.0   7.0   6.0    NaN   NaN   NaN
# e   5.0   8.0  87.0    NaN   NaN   NaN
# h   NaN   NaN   NaN    3.0   6.0   0.0
# i   NaN   NaN   NaN   42.0   7.0   6.0
# j   NaN   NaN   NaN   54.0   8.0  87.0

# %%
data1.join(data2, how='cross')
# Out:
#     kay1  key2  key3  kay11  key4  key5
# 0      1     4     8      1     4     8
# 1      1     4     8      2     3     9
# 2      1     4     8      3     6     0
# 3      1     4     8     42     7     6
# 4      1     4     8     54     8    87
# 5      2     5     9      1     4     8
# 6      2     5     9      2     3     9
# 7      2     5     9      3     6     0
# 8      2     5     9     42     7     6
# 9      2     5     9     54     8    87
# 10     3     6     0      1     4     8
# 11     3     6     0      2     3     9
# 12     3     6     0      3     6     0
# 13     3     6     0     42     7     6
# 14     3     6     0     54     8    87
# 15     4     7     6      1     4     8
# 16     4     7     6      2     3     9
# 17     4     7     6      3     6     0
# 18     4     7     6     42     7     6
# 19     4     7     6     54     8    87
# 20     5     8    87      1     4     8
# 21     5     8    87      2     3     9
# 22     5     8    87      3     6     0
# 23     5     8    87     42     7     6
# 24     5     8    87     54     8    87

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3      male  35.0      0      0            373450   8.0500  sudh        S
# 4      male  sudh      0      0            330877   8.4583  sudh        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000  sudh        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female  sudh      1      2        W./C. 6607  23.4500  sudh        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500  sudh        Q
#
# [890 rows x 11 columns]

# %%
df['fare_INR']=df['Fare'].apply(lambda x:x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3    male  35.0      0      0            373450   8.0500  sudh        S
# 4    male  sudh      0      0            330877   8.4583  sudh        Q
#
#    fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
def euro_inr(x):
    return x*80

df['fare_INR']=df['Fare'].apply(euro_inr)

# %%
df['fare_INR']
# Out:
# 0       580.000
# 1      5702.664
# 2       634.000
# 3       644.000
# 4       676.664
#          ...
# 885    1040.000
# 886    2400.000
# 887    1876.000
# 888    2400.000
# 889     620.000
# Name: fare_INR, Length: 890, dtype: float64

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3    male  35.0      0      0            373450   8.0500  sudh        S
# 4    male  sudh      0      0            330877   8.4583  sudh        Q
#
#    fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
df['Name_len']=df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3    male  35.0      0      0            373450   8.0500  sudh        S
# 4    male  sudh      0      0            330877   8.4583  sudh        Q
#
#    fare_INR  Name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# 3   644.000        24
# 4   676.664        16

# %%
def cat_fair(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "mid"
    else:
        return "high"

# %%
df['cat_fare']=df['Fare'].apply(cat_fair)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500  sudh        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250  sudh        S
# 3      male  35.0      0      0            373450   8.0500  sudh        S
# 4      male  sudh      0      0            330877   8.4583  sudh        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000  sudh        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female  sudh      1      2        W./C. 6607  23.4500  sudh        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500  sudh        Q
#
#      fare_INR  Name_len cat_fare
# 0     580.000        23    cheap
# 1    5702.664        51     high
# 2     634.000        22    cheap
# 3     644.000        24    cheap
# 4     676.664        16    cheap
# ..        ...       ...      ...
# 885  1040.000        21      mid
# 886  2400.000        28     high
# 887  1876.000        40     high
# 888  2400.000        21     high
# 889   620.000        19    cheap
#
# [890 rows x 14 columns]
